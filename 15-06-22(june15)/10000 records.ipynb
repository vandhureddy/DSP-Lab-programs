# %%
import pandas as pd
sales=pd.read_csv("10000 Sales Records.csv")

# %%
sales
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
print(sales.loc[100])
# Out:
# Region            Central America and the Caribbean
# Country                                 Saint Lucia
# Item Type                                    Snacks
# Sales Channel                                Online
# Order Priority                                    C
# Order Date                               12/25/2011
# Order ID                                  356917321
# Ship Date                                  2/4/2012
# Units Sold                                     8622
# Unit Price                                   152.58
# Unit Cost                                     97.44
# Total Revenue                           1.31554e+06
# Total Cost                                   840128
# Total Profit                                 475417
# Name: 100, dtype: object

# %%
print(sales.loc[sales["Units Sold"]<900])
# Out:
#                             Region        Country        Item Type  \
# 10              Sub-Saharan Africa         Zambia           Cereal
# 15           Australia and Oceania          Palau           Snacks
# 23                            Asia          Japan        Cosmetics
# 27                          Europe        Albania        Baby Food
# 30                          Europe        Andorra  Office Supplies
# ...                            ...            ...              ...
# 9946            Sub-Saharan Africa        Eritrea        Cosmetics
# 9950            Sub-Saharan Africa        Namibia  Office Supplies
# 9974  Middle East and North Africa        Bahrain        Beverages
# 9996                        Europe  Liechtenstein        Cosmetics
# 9999                          Asia       Mongolia           Snacks
#
#      Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 10         Offline              M   7/26/2016  773452794  8/24/2016
# ...

# %%
sales["delivered products"]=0

# %%
sales
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
sales.loc[0]
# Out:
# Region            Sub-Saharan Africa
# Country                         Chad
# Item Type            Office Supplies
# Sales Channel                 Online
# Order Priority                     L
# Order Date                 1/27/2011
# Order ID                   292494523
# Ship Date                  2/12/2011
# Units Sold                      4484
# Unit Price                    651.21
# Unit Cost                     524.96
# Total Revenue            2.92003e+06
# Total Cost               2.35392e+06
# Total Profit                  566105
# Name: 0, dtype: object

# %%
sales.loc[100,"Units Sold"]
# Out:
# 8622

# %%
type(sales)
# Out:
# pandas.core.frame.DataFrame

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          10000 non-null  object
#  1   Country         10000 non-null  object
#  2   Item Type       10000 non-null  object
#  3   Sales Channel   10000 non-null  object
#  4   Order Priority  10000 non-null  object
#  5   Order Date      10000 non-null  object
#  6   Order ID        10000 non-null  int64
#  7   Ship Date       10000 non-null  object
#  8   Units Sold      10000 non-null  int64
#  9   Unit Price      10000 non-null  float64
#  10  Unit Cost       10000 non-null  float64
#  11  Total Revenue   10000 non-null  float64
#  12  Total Cost      10000 non-null  float64
#  13  Total Profit    10000 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 1.1+ MB

# %%
sales.head(10)
# Out:
#                               Region                           Country  \
# 0                 Sub-Saharan Africa                              Chad
# 1                             Europe                            Latvia
# 2       Middle East and North Africa                          Pakistan
# 3                 Sub-Saharan Africa  Democratic Republic of the Congo
# 4                             Europe                    Czech Republic
# 5                 Sub-Saharan Africa                      South Africa
# 6                               Asia                              Laos
# 7                               Asia                             China
# 8                 Sub-Saharan Africa                           Eritrea
# 9  Central America and the Caribbean                             Haiti
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0  Office Supplies        Online              L   1/27/2011  292494523
# ...

# %%
sales.tail(10)
# Out:
#                      Region                           Country   Item Type  \
# 9990                   Asia                              Laos   Beverages
# 9991                 Europe                          Moldova       Snacks
# 9992  Australia and Oceania                        East Timor   Household
# 9993  Australia and Oceania                  Marshall Islands   Baby Food
# 9994     Sub-Saharan Africa                            Guinea      Fruits
# 9995                   Asia                              Laos   Beverages
# 9996                 Europe                     Liechtenstein   Cosmetics
# 9997     Sub-Saharan Africa  Democratic Republic of the Congo  Vegetables
# 9998     Sub-Saharan Africa                      South Africa        Meat
# 9999                   Asia                          Mongolia      Snacks
#
#      Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 9990       Offline              C   2/24/2015  651942288  2/28/2015
# ...

# %%
sales[["Country","Region"]]
# Out:
#                                Country                        Region
# 0                                 Chad            Sub-Saharan Africa
# 1                               Latvia                        Europe
# 2                             Pakistan  Middle East and North Africa
# 3     Democratic Republic of the Congo            Sub-Saharan Africa
# 4                       Czech Republic                        Europe
# ...                                ...                           ...
# 9995                              Laos                          Asia
# 9996                     Liechtenstein                        Europe
# 9997  Democratic Republic of the Congo            Sub-Saharan Africa
# 9998                      South Africa            Sub-Saharan Africa
# 9999                          Mongolia                          Asia
#
# [10000 rows x 2 columns]

# %%
sales["Country"]
# Out:
# 0                                   Chad
# 1                                 Latvia
# 2                               Pakistan
# 3       Democratic Republic of the Congo
# 4                         Czech Republic
#                       ...
# 9995                                Laos
# 9996                       Liechtenstein
# 9997    Democratic Republic of the Congo
# 9998                        South Africa
# 9999                            Mongolia
# Name: Country, Length: 10000, dtype: object

# %%
sales["Unit Price"].max()
# Out:
# 668.27

# %%
sales["Unit Price"].min()
# Out:
# 9.33

# %%
sales["Unit Price"].sum()
# Out:
# 2681431.39

# %%
sales["Unit Price"]<3000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 9995    True
# 9996    True
# 9997    True
# 9998    True
# 9999    True
# Name: Unit Price, Length: 10000, dtype: bool

# %%
sales[sales["Units Sold"]<30]
# Out:
#                                  Region             Country        Item Type  \
# 30                               Europe             Andorra  Office Supplies
# 995                  Sub-Saharan Africa              Rwanda  Office Supplies
# 1193                               Asia          Uzbekistan       Vegetables
# 1538                             Europe              Latvia           Cereal
# 1782                             Europe              Latvia    Personal Care
# 1936                 Sub-Saharan Africa                Togo        Cosmetics
# 2232                             Europe      United Kingdom        Baby Food
# 2265                 Sub-Saharan Africa             Nigeria        Household
# 3100                               Asia            Cambodia          Clothes
# 3379                 Sub-Saharan Africa               Ghana        Baby Food
# 3721       Middle East and North Africa          Azerbaijan        Baby Food
# ...

# %%
sales.head()
# Out:
#                          Region                           Country  \
# 0            Sub-Saharan Africa                              Chad
# 1                        Europe                            Latvia
# 2  Middle East and North Africa                          Pakistan
# 3            Sub-Saharan Africa  Democratic Republic of the Congo
# 4                        Europe                    Czech Republic
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0  Office Supplies        Online              L   1/27/2011  292494523
# 1        Beverages        Online              C  12/28/2015  361825549
# 2       Vegetables       Offline              C   1/13/2011  141515767
# 3        Household        Online              C   9/11/2012  500364005
# 4        Beverages        Online              C  10/27/2015  127481591
#
#    Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# ...

# %%
sales.tail()
# Out:
#                   Region                           Country   Item Type  \
# 9995                Asia                              Laos   Beverages
# 9996              Europe                     Liechtenstein   Cosmetics
# 9997  Sub-Saharan Africa  Democratic Republic of the Congo  Vegetables
# 9998  Sub-Saharan Africa                      South Africa        Meat
# 9999                Asia                          Mongolia      Snacks
#
#      Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 9995        Online              H   7/15/2014  199342048  7/31/2014
# 9996        Online              C  10/27/2012  763044106  11/1/2012
# 9997       Offline              M   2/14/2013  848579967  3/20/2013
# 9998        Online              L   2/19/2017  298185956  2/22/2017
# 9999       Offline              M   4/12/2016  824410903  4/16/2016
#
#       Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# ...

# %%
sales.describe()
# Out:
#            Order ID    Units Sold    Unit Price     Unit Cost  Total Revenue  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   1.000000e+04
# mean   5.498719e+08   5002.855900    268.143139    188.806639   1.333355e+06
# std    2.607835e+08   2873.246454    217.944092    176.445907   1.465026e+06
# min    1.000892e+08      2.000000      9.330000      6.920000   1.679400e+02
# 25%    3.218067e+08   2530.750000    109.280000     56.670000   2.885511e+05
# 50%    5.485663e+08   4962.000000    205.700000    117.110000   8.000512e+05
# 75%    7.759981e+08   7472.000000    437.200000    364.690000   1.819143e+06
# max    9.999342e+08  10000.000000    668.270000    524.960000   6.680027e+06
#
#          Total Cost  Total Profit
# count  1.000000e+04  1.000000e+04
# mean   9.382658e+05  3.950893e+05
# std    1.145914e+06  3.775550e+05
# min    1.245600e+02  4.338000e+01
# 25%    1.647855e+05  9.832914e+04
# 50%    4.816058e+05  2.890990e+05
# ...

# %%
sales[0:4]
# Out:
#                          Region                           Country  \
# 0            Sub-Saharan Africa                              Chad
# 1                        Europe                            Latvia
# 2  Middle East and North Africa                          Pakistan
# 3            Sub-Saharan Africa  Democratic Republic of the Congo
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0  Office Supplies        Online              L   1/27/2011  292494523
# 1        Beverages        Online              C  12/28/2015  361825549
# 2       Vegetables       Offline              C   1/13/2011  141515767
# 3        Household        Online              C   9/11/2012  500364005
#
#    Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0  2/12/2011        4484      651.21     524.96     2920025.64  2353920.64
# 1  1/23/2016        1075       47.45      31.79       51008.75    34174.25
# ...

# %%
sales.sort_index(axis=1,ascending=False)
# Out:
#       Units Sold  Unit Price  Unit Cost  Total Revenue  Total Profit  \
# 0           4484      651.21     524.96     2920025.64     566105.00
# 1           1075       47.45      31.79       51008.75      16834.50
# 2           6515      154.06      90.93     1003700.90     411291.95
# 3           7683      668.27     502.54     5134318.41    1273303.59
# 4           3491       47.45      31.79      165647.95      54669.06
# ...          ...         ...        ...            ...           ...
# 9995        8597       47.45      31.79      407927.65     134629.02
# 9996         562      437.20     263.33      245706.40      97714.94
# 9997        2524      154.06      90.93      388847.44     159340.12
# 9998        8706      421.89     364.69     3672974.34     497983.20
# 9999         361      152.58      97.44       55081.38      19905.54
#
#       Total Cost  Ship Date Sales Channel                        Region  \
# ...

# %%
sales.T
# Out:
#                               0           1                             2     \
# Region          Sub-Saharan Africa      Europe  Middle East and North Africa
# Country                       Chad      Latvia                      Pakistan
# Item Type          Office Supplies   Beverages                    Vegetables
# Sales Channel               Online      Online                       Offline
# Order Priority                   L           C                             C
# Order Date               1/27/2011  12/28/2015                     1/13/2011
# Order ID                 292494523   361825549                     141515767
# Ship Date                2/12/2011   1/23/2016                      2/1/2011
# Units Sold                    4484        1075                          6515
# Unit Price                  651.21       47.45                        154.06
# Unit Cost                   524.96       31.79                         90.93
# ...

# %%
sales.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)
