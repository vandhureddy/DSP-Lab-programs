# %%
import pandas as pd
sales=pd.read_csv("1000 Sales Records.csv")

# %%
sales
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
print(sales.loc[100])
# Out:
# Region                       North America
# Country           United States of America
# Item Type                          Clothes
# Sales Channel                      Offline
# Order Priority                           C
# Order Date                      10/21/2010
# Order ID                         699368035
# Ship Date                        12/7/2010
# Units Sold                            7398
# Unit Price                          109.28
# Unit Cost                            35.84
# Total Revenue                       808453
# Total Cost                          265144
# Total Profit                        543309
# Name: 100, dtype: object

# %%
print(sales.loc[sales["Units Sold"]<900])
# Out:
#                                 Region                         Country  \
# 20               Australia and Oceania  Federated States of Micronesia
# 23                                Asia                        Mongolia
# 24   Central America and the Caribbean                         Grenada
# 32                  Sub-Saharan Africa                           Benin
# 42        Middle East and North Africa                          Turkey
# ..                                 ...                             ...
# 961       Middle East and North Africa                           Egypt
# 970  Central America and the Caribbean          Saint Kitts and Nevis
# 981              Australia and Oceania                            Fiji
# 990                 Sub-Saharan Africa                            Mali
# 996                             Europe                         Georgia
#
#            Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
sales["delivered products"]=0

# %%
sales
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
sales.loc[0]
# Out:
# Region                Middle East and North Africa
# Country                                      Libya
# Item Type                                Cosmetics
# Sales Channel                              Offline
# Order Priority                                   M
# Order Date                              10/18/2014
# Order ID                                 686800706
# Ship Date                               10/31/2014
# Units Sold                                    8446
# Unit Price                                   437.2
# Unit Cost                                   263.33
# Total Revenue                          3.69259e+06
# Total Cost                             2.22409e+06
# Total Profit                           1.46851e+06
# delivered products                               0
# Name: 0, dtype: object

# %%
sales.loc[0,"Units Sold"]
# Out:
# 8446

# %%
type(sales)
# Out:
# pandas.core.frame.DataFrame

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Region              1000 non-null   object
#  1   Country             1000 non-null   object
#  2   Item Type           1000 non-null   object
#  3   Sales Channel       1000 non-null   object
#  4   Order Priority      1000 non-null   object
#  5   Order Date          1000 non-null   object
#  6   Order ID            1000 non-null   int64
#  7   Ship Date           1000 non-null   object
#  8   Units Sold          1000 non-null   int64
#  9   Unit Price          1000 non-null   float64
#  10  Unit Cost           1000 non-null   float64
#  11  Total Revenue       1000 non-null   float64
#  12  Total Cost          1000 non-null   float64
#  13  Total Profit        1000 non-null   float64
#  14  delivered products  1000 non-null   int64
# ...

# %%
sales.head(10)
# Out:
#                               Region     Country   Item Type Sales Channel  \
# 0       Middle East and North Africa       Libya   Cosmetics       Offline
# 1                      North America      Canada  Vegetables        Online
# 2       Middle East and North Africa       Libya   Baby Food       Offline
# 3                               Asia       Japan      Cereal       Offline
# 4                 Sub-Saharan Africa        Chad      Fruits       Offline
# 5                             Europe     Armenia      Cereal        Online
# 6                 Sub-Saharan Africa     Eritrea      Cereal        Online
# 7                             Europe  Montenegro     Clothes       Offline
# 8  Central America and the Caribbean     Jamaica  Vegetables        Online
# 9              Australia and Oceania        Fiji  Vegetables       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# ...

# %%
sales.tail(10)
# Out:
#                            Region               Country   Item Type  \
# 990            Sub-Saharan Africa                  Mali   Beverages
# 991            Sub-Saharan Africa               Liberia      Cereal
# 992                        Europe           Switzerland   Beverages
# 993         Australia and Oceania                Samoa    Baby Food
# 994                          Asia                 Nepal        Meat
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 990        Online              L   3/17/2012  410452497  3/26/2012
# 991       Offline              H  12/17/2015  642683303  1/20/2016
# ...

# %%
sales[["Units Sold","Region"]]
# Out:
#      Units Sold                        Region
# 0          8446  Middle East and North Africa
# 1          3018                 North America
# 2          1517  Middle East and North Africa
# 3          3322                          Asia
# 4          9845            Sub-Saharan Africa
# ..          ...                           ...
# 995        6524  Middle East and North Africa
# 996         288                        Europe
# 997        9556  Middle East and North Africa
# 998        9801                        Europe
# 999        3528                        Europe
#
# [1000 rows x 2 columns]

# %%
sales["Region"]
# Out:
# 0      Middle East and North Africa
# 1                     North America
# 2      Middle East and North Africa
# 3                              Asia
# 4                Sub-Saharan Africa
#                    ...
# 995    Middle East and North Africa
# 996                          Europe
# 997    Middle East and North Africa
# 998                          Europe
# 999                          Europe
# Name: Region, Length: 1000, dtype: object

# %%
sales["Units Sold"].max()
# Out:
# 9998

# %%
sales["Units Sold"].min()
# Out:
# 13

# %%
sales["Units Sold"].sum()
# Out:
# 5053988

# %%
sales["Units Sold"]<3000
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: Units Sold, Length: 1000, dtype: bool

# %%
sales[sales["Units Sold"]<30]
# Out:
#                  Region      Country      Item Type Sales Channel  \
# 590  Sub-Saharan Africa  Seychelles       Household        Online
# 747  Sub-Saharan Africa   Cape Verde  Personal Care       Offline
#
#     Order Priority Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 590              C  9/28/2013  109694898  10/16/2013          13      668.27
# 747              L  7/19/2016  458942115   7/29/2016          25       81.73
#
#      Unit Cost  Total Revenue  Total Cost  Total Profit  delivered products
# 590     502.54        8687.51     6533.02       2154.49                   0
# 747      56.67        2043.25     1416.75        626.50                   0

# %%
sales.dtypes
# Out:
# Region                 object
# Country                object
# Item Type              object
# Sales Channel          object
# Order Priority         object
# Order Date             object
# Order ID                int64
# Ship Date              object
# Units Sold              int64
# Unit Price            float64
# Unit Cost             float64
# Total Revenue         float64
# Total Cost            float64
# Total Profit          float64
# delivered products      int64
# dtype: object

# %%
sales.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit  delivered products
# ...

# %%
sales.tail()
# Out:
#                            Region               Country   Item Type  \
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 995       Offline              C  4/18/2010  534085166  4/25/2010        6524
# 996       Offline              H   8/1/2011  590768182   9/7/2011         288
# 997        Online              C  5/12/2011  524363124  6/28/2011        9556
# 998       Offline              L  1/25/2016  289606320  2/14/2016        9801
# 999       Offline              C  4/10/2014  811546599   5/8/2014        3528
#
#      Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  \
# ...

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
sales.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit',
#        'delivered products'],
#       dtype='object')

# %%
sales.to_numpy()
# Out:
# array([['Middle East and North Africa', 'Libya', 'Cosmetics', ...,
#         2224085.18, 1468506.02, 0],
#        ['North America', 'Canada', 'Vegetables', ..., 274426.74,
#         190526.34, 0],
#        ['Middle East and North Africa', 'Libya', 'Baby Food', ...,
#         241840.14, 145419.62, 0],
#        ...,
#        ['Middle East and North Africa', 'United Arab Emirates',
#         'Vegetables', ..., 868927.08, 603270.28, 0],
#        ['Europe', 'Finland', 'Household', ..., 4925394.54, 1624319.73, 0],
#        ['Europe', 'Portugal', 'Cereal', ..., 413164.08, 312545.52, 0]],
#       dtype=object)

# %%
sales.describe()
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit  delivered products
# count  1.000000e+03  1.000000e+03              1000.0
# mean   9.361192e+05  3.912026e+05                 0.0
# std    1.162571e+06  3.836402e+05                 0.0
# min    1.416750e+03  5.326100e+02                 0.0
# ...

# %%
sales.T
# Out:
#                                              0              1    \
# Region              Middle East and North Africa  North America
# Country                                    Libya         Canada
# Item Type                              Cosmetics     Vegetables
# Sales Channel                            Offline         Online
# Order Priority                                 M              M
# Order Date                            10/18/2014      11/7/2011
# Order ID                               686800706      185941302
# Ship Date                             10/31/2014      12/8/2011
# Units Sold                                  8446           3018
# Unit Price                                 437.2         154.06
# Unit Cost                                 263.33          90.93
# Total Revenue                        3.69259e+06         464953
# Total Cost                           2.22409e+06         274427
# Total Profit                         1.46851e+06         190526
# ...

# %%
sales.sort_index(axis=1,ascending=False)
# Out:
#      delivered products  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 0                     0        8446      437.20     263.33     3692591.20
# 1                     0        3018      154.06      90.93      464953.08
# 2                     0        1517      255.28     159.42      387259.76
# 3                     0        3322      205.70     117.11      683335.40
# 4                     0        9845        9.33       6.92       91853.85
# ..                  ...         ...         ...        ...            ...
# 995                   0        6524      152.58      97.44      995431.92
# 996                   0         288      255.28     159.42       73520.64
# 997                   0        9556      154.06      90.93     1472197.36
# 998                   0        9801      668.27     502.54     6549714.27
# 999                   0        3528      205.70     117.11      725709.60
#
#      Total Profit  Total Cost   Ship Date Sales Channel  \
# ...

# %%
sales[0:9]
# Out:
#                               Region     Country   Item Type Sales Channel  \
# 0       Middle East and North Africa       Libya   Cosmetics       Offline
# 1                      North America      Canada  Vegetables        Online
# 2       Middle East and North Africa       Libya   Baby Food       Offline
# 3                               Asia       Japan      Cereal       Offline
# 4                 Sub-Saharan Africa        Chad      Fruits       Offline
# 5                             Europe     Armenia      Cereal        Online
# 6                 Sub-Saharan Africa     Eritrea      Cereal        Online
# 7                             Europe  Montenegro     Clothes       Offline
# 8  Central America and the Caribbean     Jamaica  Vegetables        Online
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# ...

# %%
# Out:
#   File "<ipython-input-42-2ac16276ed4c>", line 1
#     sales.loc[Ship Date[0]]
#                       ^
# SyntaxError: invalid syntax
