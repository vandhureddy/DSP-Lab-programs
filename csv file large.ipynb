# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("regional.csv")
df
# Out:
#             Series_reference   Period  Data_value       STATUS    UNITS  \
# 0     RNAA.SG01NAC34B0101AA1  2000.03       327.0        FINAL  Dollars
# 1     RNAA.SG01NAC34B0101AA1  2001.03       459.0        FINAL  Dollars
# 2     RNAA.SG01NAC34B0101AA1  2002.03       510.0        FINAL  Dollars
# 3     RNAA.SG01NAC34B0101AA1  2003.03       334.0        FINAL  Dollars
# 4     RNAA.SG01NAC34B0101AA1  2004.03       372.0        FINAL  Dollars
# ...                      ...      ...         ...          ...      ...
# 9859     RNAA.SG09NAC34B0199  2017.03     56903.0      REVISED  Dollars
# 9860     RNAA.SG09NAC34B0199  2018.03     59839.0      REVISED  Dollars
# 9861     RNAA.SG09NAC34B0199  2019.03     61987.0      REVISED  Dollars
# 9862     RNAA.SG09NAC34B0199  2020.03     64262.0      REVISED  Dollars
# 9863     RNAA.SG09NAC34B0199  2021.03     63955.0  PROVISIONAL  Dollars
#
#       MAGNTUDE                                Subject  \
# ...

# %%
df.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# STATUS               object
# UNITS                object
# MAGNTUDE              int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4      float64
# Series_title_5      float64
# dtype: object

# %%
df['Data_value'].astype('float')
# Out:
# 0         327.0
# 1         459.0
# 2         510.0
# 3         334.0
# 4         372.0
#          ...
# 9859    56903.0
# 9860    59839.0
# 9861    61987.0
# 9862    64262.0
# 9863    63955.0
# Name: Data_value, Length: 9864, dtype: float64

# %%
df['Subject'].dtype
# Out:
# dtype('O')

# %%
df['Group'].dtype
# Out:
# dtype('O')

# %%
df['MAGNTUDE'].dtype
# Out:
# dtype('int64')

# %%
df['Period'].dtype
# Out:
# dtype('float64')

# %%
df['Data_value'].dtype
# Out:
# dtype('float64')

# %%
df['UNITS'].dtype
# Out:
# dtype('O')

# %%
df['Series_title_1'].dtype
# Out:
# dtype('O')

# %%
df['Series_title_5'].dtype
# Out:
# dtype('float64')

# %%
df['Series_title_4'].dtype
# Out:
# dtype('float64')

# %%
df['Series_title_3'].dtype
# Out:
# dtype('O')

# %%
df['Series_title_2'].dtype
# Out:
# dtype('O')

# %%
df['Series_reference'].dtype
# Out:
# dtype('O')

# %%
df=pd.read_csv("regional.csv",header=None)
df
# Out:
#                           0        1           2            3        4   \
# 0           Series_reference   Period  Data_value       STATUS    UNITS
# 1     RNAA.SG01NAC34B0101AA1  2000.03         327        FINAL  Dollars
# 2     RNAA.SG01NAC34B0101AA1  2001.03         459        FINAL  Dollars
# 3     RNAA.SG01NAC34B0101AA1  2002.03         510        FINAL  Dollars
# 4     RNAA.SG01NAC34B0101AA1  2003.03         334        FINAL  Dollars
# ...                      ...      ...         ...          ...      ...
# 9860     RNAA.SG09NAC34B0199  2017.03       56903      REVISED  Dollars
# 9861     RNAA.SG09NAC34B0199  2018.03       59839      REVISED  Dollars
# 9862     RNAA.SG09NAC34B0199  2019.03       61987      REVISED  Dollars
# 9863     RNAA.SG09NAC34B0199  2020.03       64262      REVISED  Dollars
# 9864     RNAA.SG09NAC34B0199  2021.03       63955  PROVISIONAL  Dollars
#
#             5                                      6   \
# ...

# %%
b=pd.read_csv("C:\\Users\\SATYA SRI\\Pictures\\regional.csv")
b
# Out:
#             Series_reference   Period  Data_value       STATUS    UNITS  \
# 0     RNAA.SG01NAC34B0101AA1  2000.03       327.0        FINAL  Dollars
# 1     RNAA.SG01NAC34B0101AA1  2001.03       459.0        FINAL  Dollars
# 2     RNAA.SG01NAC34B0101AA1  2002.03       510.0        FINAL  Dollars
# 3     RNAA.SG01NAC34B0101AA1  2003.03       334.0        FINAL  Dollars
# 4     RNAA.SG01NAC34B0101AA1  2004.03       372.0        FINAL  Dollars
# ...                      ...      ...         ...          ...      ...
# 9859     RNAA.SG09NAC34B0199  2017.03     56903.0      REVISED  Dollars
# 9860     RNAA.SG09NAC34B0199  2018.03     59839.0      REVISED  Dollars
# 9861     RNAA.SG09NAC34B0199  2019.03     61987.0      REVISED  Dollars
# 9862     RNAA.SG09NAC34B0199  2020.03     64262.0      REVISED  Dollars
# 9863     RNAA.SG09NAC34B0199  2021.03     63955.0  PROVISIONAL  Dollars
#
#       MAGNTUDE                                Subject  \
# ...

# %%
b.to_excel("regional.csv.xlsx")
b
# Out:
#             Series_reference   Period  Data_value       STATUS    UNITS  \
# 0     RNAA.SG01NAC34B0101AA1  2000.03       327.0        FINAL  Dollars
# 1     RNAA.SG01NAC34B0101AA1  2001.03       459.0        FINAL  Dollars
# 2     RNAA.SG01NAC34B0101AA1  2002.03       510.0        FINAL  Dollars
# 3     RNAA.SG01NAC34B0101AA1  2003.03       334.0        FINAL  Dollars
# 4     RNAA.SG01NAC34B0101AA1  2004.03       372.0        FINAL  Dollars
# ...                      ...      ...         ...          ...      ...
# 9859     RNAA.SG09NAC34B0199  2017.03     56903.0      REVISED  Dollars
# 9860     RNAA.SG09NAC34B0199  2018.03     59839.0      REVISED  Dollars
# 9861     RNAA.SG09NAC34B0199  2019.03     61987.0      REVISED  Dollars
# 9862     RNAA.SG09NAC34B0199  2020.03     64262.0      REVISED  Dollars
# 9863     RNAA.SG09NAC34B0199  2021.03     63955.0  PROVISIONAL  Dollars
#
#       MAGNTUDE                                Subject  \
# ...

# %%
rows=len(df.axes[0])
print(rows)
# Out:
# 9865

# %%
columns=len(df.axes[1])
print(columns)
# Out:
# 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9865 entries, 0 to 9864
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       9865 non-null   object
#  1   1       9865 non-null   object
#  2   2       9613 non-null   object
#  3   3       9865 non-null   object
#  4   4       9865 non-null   object
#  5   5       9865 non-null   object
#  6   6       9865 non-null   object
#  7   7       9865 non-null   object
#  8   8       9865 non-null   object
#  9   9       9865 non-null   object
#  10  10      9469 non-null   object
#  11  11      1 non-null      object
#  12  12      1 non-null      object
# dtypes: object(13)
# memory usage: 1002.0+ KB

# %%
df.head()
# Out:
#                        0        1           2       3        4         5   \
# 0        Series_reference   Period  Data_value  STATUS    UNITS  MAGNTUDE
# 1  RNAA.SG01NAC34B0101AA1  2000.03         327   FINAL  Dollars         6
# 2  RNAA.SG01NAC34B0101AA1  2001.03         459   FINAL  Dollars         6
# 3  RNAA.SG01NAC34B0101AA1  2002.03         510   FINAL  Dollars         6
# 4  RNAA.SG01NAC34B0101AA1  2003.03         334   FINAL  Dollars         6
#
#                                       6   \
# 0                                Subject
# 1  Regional Gross Domestic Product - RNA
# 2  Regional Gross Domestic Product - RNA
# 3  Regional Gross Domestic Product - RNA
# 4  Regional Gross Domestic Product - RNA
#
#                                                7   \
# 0                                           Group
# 1  Gross domestic product, by region and industry
# 2  Gross domestic product, by region and industry
# 3  Gross domestic product, by region and industry
# ...

# %%
df.size
# Out:
# 128245

# %%
df.shape
# Out:
# (9865, 13)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9865, step=1)

# %%
len(df.index)
# Out:
# 9865

# %%
import pandas as pd
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'STATUS', 'UNITS',
#        'MAGNTUDE', 'Subject', 'Group', 'Series_title_1', 'Series_title_2',
#        'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')
