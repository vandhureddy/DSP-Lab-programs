# %%
import matplotlib.pyplot as plt
x=[1,2,3,9,6,7,4,6,8,4,10]
y=[10,30,50,78,65,45,33,25,98,88,70]
color=['red','blue','yellow','green','hotpink','brown','pink','cyan','r','b','y']
size=[162,296,33,45,98,105,57,88,37,200,100]
plt.scatter(x,y,marker="*",c=color,s=size,edgecolor='black',linewidth=1)
plt.show()

# %%
import numpy as np
print(np.random.random(40))
# Out:
# [0.80885171 0.54370827 0.85631106 0.19368289 0.8059404  0.54507287
#  0.25620864 0.5467338  0.29141527 0.87845286 0.07533088 0.9824627
#  0.44909351 0.65122225 0.03297935 0.86534394 0.28828048 0.47845891
#  0.32603389 0.18170231 0.51023746 0.49420619 0.59582948 0.94286376
#  0.22482189 0.19666357 0.88603047 0.94758745 0.51517833 0.39837136
#  0.65604975 0.48729646 0.89947311 0.26087638 0.58842519 0.74753014
#  0.46907973 0.37083806 0.08853818 0.78451559]

# %%
import numpy as np
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)
plt.scatter(x,y,z)
plt.scatter(x,y,marker='s',c='r',s=100,linewidth=3,edgecolor='green',alpha=0.2)

# %%
import numpy as np
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)
color=['red','blue','yellow','green','hotpink','brown','pink','cyan','r','b','red','blue','yellow','green','hotpink','brown','pink','cyan','r','b','red','blue','yellow','green','hotpink','brown','pink','cyan','r','b','red','blue','yellow','green','hotpink','brown','pink','cyan','r','b']
plt.scatter(x,y,z*500,marker='>',alpha=0.3,c=color)

# %%
data=[10,20,40,50,70]
plt.boxplot(data)
plt.show()

# %%
import numpy as n
print(n.random.rand(10,5))
# Out:
# [[0.89118853 0.00881321 0.55620968 0.58696378 0.65848894]
#  [0.10817016 0.02309058 0.06873917 0.02174791 0.24654455]
#  [0.3654777  0.45328479 0.6980496  0.93783905 0.45800553]
#  [0.79548549 0.94880569 0.76735477 0.7101088  0.16320144]
#  [0.28468833 0.41839215 0.12690323 0.7440252  0.87313519]
#  [0.98278422 0.87502277 0.03311697 0.83495466 0.70053724]
#  [0.01259523 0.63756492 0.72417298 0.20694476 0.49874943]
#  [0.30211933 0.48852296 0.84746609 0.36247152 0.6157339 ]
#  [0.44801138 0.15348729 0.2649107  0.47316573 0.77731615]
#  [0.42536585 0.30757126 0.87462852 0.13069882 0.29375406]]

# %%
x=n.random.rand(5)
y=n.random.rand(5)
print(x,y)
d=x+y
plt.boxplot(d)
plt.show()
# Out:
# [0.6909494  0.91921523 0.74507204 0.3799517  0.63962295] [0.06144217 0.26244149 0.05651734 0.79467453 0.41083291]

# %%
data1=[10,20,30,40,50]
data2=[10,20,40,50,70]
data=data1+data2
print(data)
plt.boxplot(data)
# Out:
# [10, 20, 30, 40, 50, 10, 20, 40, 50, 70]
# {'whiskers': [<matplotlib.lines.Line2D at 0x216e3f16be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x216e3f251c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x216e3f16910>],
#  'medians': [<matplotlib.lines.Line2D at 0x216e3f25760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x216e3f25a30>],
#  'means': []}

# %%
import pandas as p
x=n.random.rand(10,5)
print(x)
df=p.DataFrame(x*10,columns=['A','B','C','D','E'])
df.plot.box()
plt.show()
df['A'].plot(kind="pie")
# Out:
# [[0.71876858 0.33841995 0.46705623 0.05562958 0.24105163]
#  [0.14612512 0.0425923  0.93131801 0.262194   0.8202647 ]
#  [0.10141997 0.00367872 0.76817946 0.63490144 0.52901646]
#  [0.1674064  0.15436064 0.84685499 0.7186746  0.90303164]
#  [0.70150222 0.61015366 0.68451763 0.26662501 0.07847416]
#  [0.96654199 0.46877233 0.998434   0.59370473 0.04081168]
#  [0.55774091 0.30660641 0.02990153 0.05499411 0.20385909]
#  [0.72544857 0.39900329 0.89430012 0.0451459  0.01016034]
#  [0.85044987 0.2485896  0.01323644 0.09805451 0.80499662]
#  [0.3231917  0.87859583 0.05792349 0.20745168 0.84428951]]
# <AxesSubplot:ylabel='A'>

# %%
import pandas as pd
df=pd.DataFrame(np.random.rand(10,5)*10,columns=['A','B','C','D','E'])
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>
